# %%
from sklearn.model_selection import train_test_split , GridSearchCV
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
import pandas as pd

# %%
data = pd.read_csv("../dataset/housing.csv")
features = ["CRIM","ZN","INDUS","CHAS","NOX","RM","AGE","DIS","RAD","TAX","PTRATIO","B","LSTAT","MEDV"]

data.columns = features

data.dropna(inplace=True)

x , y = data.drop(columns=["MEDV"]) , data["MEDV"]

x_train , x_test , y_train , y_test =  train_test_split(x,y,test_size=0.2,random_state=42)

# %%
data.to_csv("../dataset/house.csv",index=False)

# %%
forest_params = [{'max_depth': list(range(10, 15)), 'max_features': list(range(1,10))}]

clf = GridSearchCV(RandomForestRegressor(), forest_params, cv = 5, scoring='neg_mean_squared_error')

clf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid=[{'max_depth': [10, 11, 12, 13, 14],
#                           'max_features': [1, 2, 3, 4, 5, 6, 7, 8, 9]}],
#              scoring='neg_mean_squared_error')

# %%
print(clf.best_params_)
print(clf.best_score_)
# Out:
# {'max_depth': 12, 'max_features': 4}
# -13.469705975267876

# %%
data.shape
# Out:
# (505, 14)

# %%
import numpy as np
np.var(y_train)
# Out:
# np.float64(91.22238426379765)

# %%
import joblib
joblib.dump(clf,"../model/model.pkl")
# Out:
# ['../model/model.pkl']

# %%
loaded_model = joblib.load("../model/model.pkl")
loaded_model.predict(x_test)
# Out:
# array([22.60746924, 32.79878427, 15.99503023, 23.7711609 , 34.39613333,
#        21.31626909, 14.91378333, 15.30492454, 20.65033575, 20.80366297,
#        22.73852137, 20.39024161, 27.54865595, 20.97376099, 20.61769774,
#        22.23233671, 19.69130399,  9.33735714, 36.62334286, 14.2853205 ,
#        25.84567463, 31.8175582 , 19.26705695, 22.48546765, 14.93517549,
#        10.99866667, 27.2047371 , 21.52287675, 19.67613924, 21.04189366,
#        25.02064273, 12.95668333, 22.33641919, 21.05659124, 19.39721377,
#        17.69298333, 36.4912    , 19.8984177 , 18.53278291, 24.21136073,
#        18.45399799, 16.51572173, 22.11066025, 20.89535658, 23.95375693,
#        28.32154325, 15.19418944, 21.53861647, 18.22724514, 23.33314576,
#        20.33367615, 42.68741667, 15.78676589, 19.36563436, 22.33165251,
#        21.31888105, 15.84487768, 34.61814286, 27.06616899, 21.83859901,
#        32.26313333, 24.61121314, 21.95033137, 19.83846023, 14.76783333,
#        20.76180452, 13.6228455 , 23.23446178, 35.53392619, 15.46716   ,
#        19.81496347, 13.88893333, 20.33491555, 21.21890435, 21.23983562,
#         8.16543016, 18.81165045, 47.104     , 11.43263333, 12.46862564,
#        24.07747807, 13.43169091, 39.56200952, 10.6275706 , 20.40976   ,
#        21.84061719, 15.12390563, 23.7109615 , 22.21377396, 16.35493613,
#        25.55813746, 19.85875715, 19.65473541, 27.85456863, 25.86025531,
#        17.60316968, 22.16737766, 12.6004    , 25.27081863, 24.12968755,
#        23.01052097])

# %%
clf.predict(x_test)
# Out:
# array([22.60746924, 32.79878427, 15.99503023, 23.7711609 , 34.39613333,
#        21.31626909, 14.91378333, 15.30492454, 20.65033575, 20.80366297,
#        22.73852137, 20.39024161, 27.54865595, 20.97376099, 20.61769774,
#        22.23233671, 19.69130399,  9.33735714, 36.62334286, 14.2853205 ,
#        25.84567463, 31.8175582 , 19.26705695, 22.48546765, 14.93517549,
#        10.99866667, 27.2047371 , 21.52287675, 19.67613924, 21.04189366,
#        25.02064273, 12.95668333, 22.33641919, 21.05659124, 19.39721377,
#        17.69298333, 36.4912    , 19.8984177 , 18.53278291, 24.21136073,
#        18.45399799, 16.51572173, 22.11066025, 20.89535658, 23.95375693,
#        28.32154325, 15.19418944, 21.53861647, 18.22724514, 23.33314576,
#        20.33367615, 42.68741667, 15.78676589, 19.36563436, 22.33165251,
#        21.31888105, 15.84487768, 34.61814286, 27.06616899, 21.83859901,
#        32.26313333, 24.61121314, 21.95033137, 19.83846023, 14.76783333,
#        20.76180452, 13.6228455 , 23.23446178, 35.53392619, 15.46716   ,
#        19.81496347, 13.88893333, 20.33491555, 21.21890435, 21.23983562,
#         8.16543016, 18.81165045, 47.104     , 11.43263333, 12.46862564,
#        24.07747807, 13.43169091, 39.56200952, 10.6275706 , 20.40976   ,
#        21.84061719, 15.12390563, 23.7109615 , 22.21377396, 16.35493613,
#        25.55813746, 19.85875715, 19.65473541, 27.85456863, 25.86025531,
#        17.60316968, 22.16737766, 12.6004    , 25.27081863, 24.12968755,
#        23.01052097])
